# %%
# Setup for notebooks as they have no packages!
import sys
# !conda install --yes --prefix {sys.prefix} numpy

# Import numpy
import numpy as np

# multiply your matricies
x = [1, 2, 3]
y = [1, 4, 3]

# Cross product them
crossproduct_of_matrix = np.cross(x, y)

# Print the result
print('Print the cross product result:')
print(crossproduct_of_matrix)
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.5.10
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.
#
# Print the result:
# [-6  0  2]

# %%
# Setup for notebooks as they have no packages!
import sys
# !conda install --yes --prefix {sys.prefix} numpy

# Import numpy
import numpy as np

# multiply your matricies
x = [1, 2, 3]
y = [1, 4, 3]

# Cross product them
dotproduct_of_matrix = np.dot(x, y)

# Print the result
print('Print the dot product result:')
print(dotproduct_of_matrix)
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.5.11
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/andrewevans/anaconda2/envs/py36
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     numpy-1.15.1               |   py36h6a91979_0          37 KB
#
# The following packages will be UPDATED:
#
#     numpy: 1.15.1-py36h648b28d_0 --> 1.15.1-py36h6a91979_0
#
#
# Downloading and Extracting Packages
# numpy 1.15.1: ########################################################## | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Print the dot product result:
# 18

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3)
plt.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], color='darkgreen', marker='^')
plt.xlim(0.5, 4.5)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.5, 4.5)
